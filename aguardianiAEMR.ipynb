# %% [markdown]
# <center><h1 style="color:#D4AF37"> ⚡⚡ AEMR Data Analysis ⚡⚡</h1>

# %% [markdown]
# <img src = "https://images.squarespace-cdn.com/content/v1/551972d8e4b0d571edc2e2c8/8f3abd33-0916-4415-9b24-593eea1d1e3c/Screen+Shot+2022-04-20+at+12.41.24+PM.png">
#
#
# It’s time for you to apply your budding SQL Competencies to analyse data for the American Energy Market Regulator (AEMR).
#
# The analytics team has supplied you with the following table extract that contains all the data you need to analyse for the `AEMR` outages.
#
# <li> AEMR_Outage_Table </li>
#
# Now let's revisit the business problem below and understand what we're seeking to solve.

# %% [markdown]
# <h1 style="color:#D4AF37"> What's the Business Problem? 💰</h1>
#
# The American Energy Market Regulator (AEMR) is responsible for looking after the
# United States of America’s domestic energy network. The regulator’s responsibility is to
# ensure that America’s energy network remains reliable with minimal disruptions, which
# are known as outages.
#
# There are four key types of outages:
#
# ● Consequential
#
# ● Forced
#
# ● Opportunistic
#
# ● Planned
#
# Recently, the AEMR management team has been increasingly aware of a large number
# of energy providers that submitted outages over the 2016 and 2017 calendar years. The
# management team has expressed a desire to have the following two areas of concern
# addressed:
#
# <b> A) Energy Stability and Market Outages
#     <p>
# B) Energy Losses and Market Reliability </b>
#
# As an analyst within the data and reporting team, you have been asked to address these
# two immediate areas of concern. Feel free to also explore beyond the queries asked and provide additional insights that you feel may be of interest to the management team.

# %% [markdown]
# <h3 style="color:#D4AF37">  SQLite Refresher ⚙️ </h3>
#
# We've pre-loaded the data you need to access in the `AEMR.db` we've included. We'll have you write SQL below where all your SQL queries will be stored in this notebook as a reference you can use when you review your data analysis in Tableau. </b>.
#
# To load the `AEMR.db` file into this notebook, run the below cells.
#
# <b> ⚠️ Please remember that everytime you close this file and re-open this, you'll need to re-run the cells below. ⚠️ </b>

# %% [markdown]
# <b>⚠️ Note: Remember, you'll need to start each cell with the **`%%sql`** line, which allows us to execute SQL from within this notebook.</b>

# %%
# %%capture
# !pip install ipython-sql sqlalchemy
import sqlalchemy
sqlalchemy.create_engine("sqlite:///AEMR.db")
# %load_ext sql
# %sql sqlite:///AEMR.db

# %%
# %%js
# require(['notebook/js/codecell'], function (codecell) {
#     codecell.CodeCell.options_default.highlight_modes['magic_text/x-mssql'] = { 'reg': [/%?%sql/] };
#     Jupyter.notebook.events.one('kernel_ready.Kernel', function () {
#         Jupyter.notebook.get_cells().map(function (cell) {
#             if (cell.cell_type == 'code') { cell.auto_highlight(); }
#         });
#     });
# });

# %% [markdown]
# We've included an example of how you would write a query against the database below:
#
# ~~~sql
# %%sql
# SELECT
# *
# FROM AEMR_Outage_Table
# LIMIT 10
# ~~~
#
# Once you've written your SQL, you'll then need to press `Ctrl` + `Enter` to run the cell.
# Otherwise, you can just press `run` at the very top of your screen, to run the specific cell.
#
# For your convenience, we've included a <b style = "color:#5D3FD3"> subset of the answers </b> under the header `Expected Output (Sample)`. These small subsets also include all the `columns` you'll need to include in your Query, so you know what to expect!
#
# Good luck!
#
# <b>PS: In case any of you get stuck regarding how to tackle any of the questions, we've included a breakdown <a href = "https://drive.google.com/file/d/1sXBGV5MZooZ7L38WYyXf9lIaA5sdKL7X/view?usp=share_link"> here</a> where Chris walks through how to tackle each question! Feel free to use this when you're stuck and you can't book a Mentor Call! </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part I. Energy Stability & Market Outages ⚡ </h3>
#
# Energy stability is one of the key themes the AEMR management team cares about. To ensure energy security and reliability, AEMR needs to understand the following:
# <p>
# <b>
#
# <li> What are the most common outage types and how long do they tend to last?
# <li> How frequently do the outages occur?
# <li> Are there any energy providers which have more outages than their peers which may be indicative of being unreliable?
#
# <p>
#
# <u style="color:Maroon"> Please note that throughout the entire case study, we are interested ONLY in the Outages where Status = Approved. We don't have any interest in Outages that were cancelled or not approved. This means your WHERE Clause will ALWAYS contain the field `Where Status = Approved` </u>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question One </h3>
#
# <b> Write a SQL Statement to `COUNT` the number of valid (i.e. `Status = Approved`) Outage Events sorted by their respective `Outage_Reason` (i.e. `Forced`, `Consequential`, `Scheduled`, `Opportunistic`) over the 2016 & 2017 Periods. </b>
#
# Do we notice anything regarding the trends for specific Outages over the 2016 / 2017 Period?

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %% [markdown]
# <b>⚠️ Note: Remember, you'll need to start each cell with the **`%%sql`** line, which allows us to execute SQL from within this notebook.</b>

# %%
# %%sql
# SELECT COUNT (EventID) AS "Total_Number_Outages", Outage_Reason, Year
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
# AND year BETWEEN 2016 AND 2017
# GROUP BY outage_reason, year
# ORDER BY year ASC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(181, 'Consequential', 2016),
#  (1264, 'Forced', 2016),
#  (106, 'Opportunistic Maintenance (Planned)', 2016),
#  (380, 'Scheduled (Planned)', 2016),
#  (127, 'Consequential', 2017),
#  (1622, 'Forced', 2017),
#  (102, 'Opportunistic Maintenance (Planned)', 2017),
#  (320, 'Scheduled (Planned)', 2017)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(181, 'Consequential', 2016),
#  (1264, 'Forced', 2016),
#  (106, 'Opportunistic Maintenance (Planned)', 2016),
#  (380, 'Scheduled (Planned)', 2016)]

# %% [markdown]
# Now how about examining some monthly trends? Do we note any behaviours across the months that indicate certain months having more reliability issues over other months?

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Two </h3>

# %% [markdown]
# <b> i) Write a SQL Statement showing the `Total` of all Outage Types (Forced, Consequential, Scheduled, Opportunistic) where the `Status = Approved`, that occurred for both 2016 and 2017, grouped by `Year` and `Month`.  per month (i.e. 1 – 12). Order by `Year`, `Month`, `Total_Number_Outages` in Descending Order.
#
#
# ii) Building on the query you write in i), group the results by `Outage Type`, `Year` and `Month`. This is so you can identify whether there is any outage type specifically increasing on a monthly basis when comparing 2016 to 2017. </b>
#
#
# <b>⚠️Hint: You might find it helpful to create a small Common Table Expression to address these two questions! </b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
#
# SELECT Year, Month,
# COUNT (EventID) AS Total_Number_Outages
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
# AND Year BETWEEN 2016 AND 2017
# AND Outage_Reason = 'Forced'
# GROUP BY Month, Year
# ORDER BY Month, Year ASC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1, 134),
#  (2017, 1, 70),
#  (2016, 2, 149),
#  (2017, 2, 97),
#  (2016, 3, 94),
#  (2017, 3, 53),
#  (2016, 4, 86),
#  (2017, 4, 73),
#  (2016, 5, 101),
#  (2017, 5, 105),
#  (2016, 6, 112),
#  (2017, 6, 172),
#  (2016, 7, 80),
#  (2017, 7, 182),
#  (2016, 8, 152),
#  (2017, 8, 170),
#  (2016, 9, 96),
#  (2017, 9, 137),
#  (2016, 10, 67),
#  (2017, 10, 207),
#  (2016, 11, 127),
#  (2017, 11, 145),
#  (2016, 12, 66),
#  (2017, 12, 211)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1, 191),
#  (2016, 2, 227),
#  (2016, 3, 136),
#  (2016, 4, 134),
#  (2016, 5, 174)]

# %% [markdown]
# Hmm. Interesting. We've now identified a specific outage type is rapidly increasing from 2016 to 2017. However, frequency is just one aspect we care about. We also care about the <b> `duration` </b> of our ouatges.
#
# In other words, if an outage is very short, we aren't as concerned. However, if the outage is very long, this then has the risk of threatening our energy supplies. We want to identify the problematic energy providers here. This leads us to our next question below.

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Three </h3>

# %% [markdown]
# <b>Write a SQL statement that calculates 1) The `Total_Number_Outage_Events` and 2) The <b> `Average Duration`</b> in <u>DAYS</u> for each `Participant Code` and `Outage Type` over the 2016 and 2017 Period where the `Status = Approved`.
# Order by `Total_Number_Outage_Events` in Descending Order, `Reason` and `Year`.
#
# Please note the average duration in days should be rounded to 2 decimal places for ease of comparison. When calculating the average duration, please note that you'll need to use the following fields:
#
# `Start_Time` and `End_Time`. </b>
#
# <b>⚠️ Hint:</b> If you're not sure how to calculate the difference between the `start_time` and `end_time` , reference this link <a href ="https://learnsql.com/cookbook/how-to-calculate-the-difference-between-two-timestamps-in-sqlite/"> here </a>
#
# We've included an example below of how you could use the `JULIANDAY()` function! Remember, the `JULIANDAY()` function returns the results in days, including the fractional component. Some of the date(s) are flipped in the dataset, so you'll need to use the ABS() function to ensure you don't return any negative values!
#
# ~~~sql
# %%sql
#
# SELECT
#         AVG((ABS(JULIANDAY(Date_2) - JULIANDAY(Date1)))
# FROM Some_Database
# ~~~

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# SELECT
#     Participant_Code,
#     Outage_Reason,
#     Year,
#     COUNT (EventID) AS Total_Number_Outage_Events,
#     ROUND (AVG(ABS(JULIANDAY(End_Time)-JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days
# FROM
#     AEMR_Outage_Table
# WHERE
#     Status = 'Approved'
#     AND YEAR BETWEEN 2016 AND 2017
# GROUP BY
#     Participant_Code, Outage_Reason, Year
# ORDER BY
#     Total_Number_Outage_Events DESC, Outage_Reason, Year;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07),
#  ('GW', 'Forced', 2016, 317, 0.38),
#  ('GW', 'Forced', 2017, 227, 1.06),
#  ('AURICON', 'Forced', 2016, 208, 0.07),
#  ('AUXC', 'Forced', 2016, 206, 0.08),
#  ('MELK', 'Forced', 2017, 177, 2.28),
#  ('TRMOS', 'Forced', 2017, 172, 0.42),
#  ('MELK', 'Forced', 2016, 157, 0.83),
#  ('PUG', 'Forced', 2017, 135, 0.25),
#  ('AUXC', 'Forced', 2017, 120, 0.02),
#  ('MELK', 'Scheduled (Planned)', 2016, 85, 4.61),
#  ('PJRH', 'Forced', 2016, 81, 1.22),
#  ('KORL', 'Forced', 2017, 76, 1.21),
#  ('PJRH', 'Forced', 2017, 72, 0.84),
#  ('MELK', 'Scheduled (Planned)', 2017, 70, 6.89),
#  ('PMC', 'Forced', 2016, 69, 0.49),
#  ('TRMOS', 'Forced', 2016, 65, 0.19),
#  ('KORL', 'Forced', 2016, 53, 0.38),
#  ('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89),
#  ('COLLGAR', 'Forced', 2017, 45, 1.38),
#  ('GW', 'Scheduled (Planned)', 2016, 45, 4.43),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45),
#  ('AURICON', 'Consequential', 2017, 42, 0.21),
#  ('AURICON', 'Consequential', 2016, 41, 0.13),
#  ('PMC', 'Forced', 2017, 40, 0.04),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 39, 0.24),
#  ('PJRH', 'Scheduled (Planned)', 2016, 38, 2.37),
#  ('ENRG', 'Scheduled (Planned)', 2017, 37, 4.96),
#  ('PJRH', 'Scheduled (Planned)', 2017, 35, 2.61),
#  ('TSLA_MGT', 'Consequential', 2016, 30, 0.44),
#  ('COLLGAR', 'Forced', 2016, 29, 1.11),
#  ('ENRG', 'Scheduled (Planned)', 2016, 29, 4.85),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 28, 0.99),
#  ('PMC', 'Scheduled (Planned)', 2016, 27, 1.9),
#  ('GW', 'Scheduled (Planned)', 2017, 26, 2.65),
#  ('PUG', 'Forced', 2016, 24, 0.92),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 24, 0.71),
#  ('TSLA_MGT', 'Consequential', 2017, 23, 0.34),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.18),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 23, 1.97),
#  ('ENRG', 'Forced', 2016, 21, 2.24),
#  ('GW', 'Consequential', 2016, 20, 0.18),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 20, 0.31),
#  ('KORL', 'Scheduled (Planned)', 2016, 20, 6.96),
#  ('STHRNCRS', 'Forced', 2017, 18, 0.26),
#  ('MUND', 'Scheduled (Planned)', 2016, 18, 3.53),
#  ('EUCT', 'Consequential', 2016, 17, 0.41),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2017, 16, 0.65),
#  ('PUG', 'Scheduled (Planned)', 2016, 16, 1.47),
#  ('KORL', 'Scheduled (Planned)', 2017, 16, 3.38),
#  ('ENRG', 'Consequential', 2016, 15, 0.57),
#  ('MUND', 'Forced', 2017, 15, 0.19),
#  ('EUCT', 'Consequential', 2017, 14, 0.32),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 14, 0.22),
#  ('STHRNCRS', 'Scheduled (Planned)', 2017, 14, 0.68),
#  ('STHRNCRS', 'Forced', 2016, 13, 0.33),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.28),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 13, 0.62),
#  ('COLLGAR', 'Consequential', 2016, 12, 0.6),
#  ('DNHR', 'Consequential', 2017, 12, 0.24),
#  ('MCG', 'Forced', 2017, 12, 0.28),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 4.28),
#  ('PMC', 'Scheduled (Planned)', 2017, 12, 1.7),
#  ('DNHR', 'Consequential', 2016, 11, 0.28),
#  ('EUCT', 'Forced', 2016, 11, 5.9),
#  ('PUG', 'Scheduled (Planned)', 2017, 11, 2.25),
#  ('PMC', 'Consequential', 2016, 10, 0.28),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.24),
#  ('STHRNCRS', 'Consequential', 2016, 9, 0.22),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 9, 0.21),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 9, 6.36),
#  ('PMC', 'Consequential', 2017, 8, 3.52),
#  ('WGUTD', 'Forced', 2017, 8, 3.44),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.15),
#  ('MELK', 'Consequential', 2016, 7, 0.76),
#  ('ENRG', 'Consequential', 2017, 7, 0.27),
#  ('ENRG', 'Forced', 2017, 7, 0.26),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 7, 0.21),
#  ('MUND', 'Scheduled (Planned)', 2017, 7, 1.7),
#  ('WGUTD', 'Consequential', 2016, 6, 1.99),
#  ('KORL', 'Consequential', 2017, 6, 2.24),
#  ('COLLGAR', 'Consequential', 2017, 5, 0.23),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.33),
#  ('TRMOS', 'Scheduled (Planned)', 2016, 5, 1.42),
#  ('GW', 'Consequential', 2017, 4, 0.24),
#  ('MUND', 'Forced', 2016, 4, 0.37),
#  ('TSLA_MGT', 'Forced', 2017, 4, 0.31),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.47),
#  ('TRMOS', 'Scheduled (Planned)', 2017, 4, 2.31),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06),
#  ('EUCT', 'Forced', 2017, 3, 0.03),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.24),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.35),
#  ('MCG', 'Consequential', 2016, 2, 0.26),
#  ('STHRNCRS', 'Consequential', 2017, 2, 0.26),
#  ('MCG', 'Consequential', 2017, 2, 0.23),
#  ('WGUTD', 'Forced', 2016, 2, 0.02),
#  ('TSLA_MGT', 'Forced', 2016, 2, 0.25),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.05),
#  ('AUXC', 'Scheduled (Planned)', 2016, 2, 1.25),
#  ('AUXC', 'Consequential', 2016, 1, 0.96),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04),
#  ('AUXC', 'Consequential', 2017, 1, 0.1),
#  ('MCG', 'Forced', 2016, 1, 0.79),
#  ('DNHR', 'Forced', 2016, 1, 0.4),
#  ('DNHR', 'Forced', 2017, 1, 0.48),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.6),
#  ('TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.06),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.08),
#  ('STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.06),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42),
#  ('WGUTD', 'Scheduled (Planned)', 2017, 1, 10.58),
#  ('AUXC', 'Scheduled (Planned)', 2017, 1, 2.88)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07),
#  ('GW', 'Forced', 2016, 317, 0.38),
#  ('GW', 'Forced', 2017, 227, 1.06),
#  ('AURICON', 'Forced', 2016, 208, 0.07),
#  ('AUXC', 'Forced', 2016, 206, 0.08)]

# %% [markdown]
# Now we're getting somewhere...!
# We've identified participants who are having many outages, as well as participants who have been offline for the longest durations.
#
# Armed with this information, it's important we're able to classify our participants accordingly based on reliability metrics of uptime.
#
# We classify a participant based off the following criteria:
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day)</li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours</li>
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Four </h3>

# %% [markdown]
# <b> Using the above criteria for context, write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> that is based off their Average Outage Duration Time. Please note that this is for all valid (i.e. `Where status = approved`) outage types (Forced, Consequential, Scheduled, Opportunistic) for <u>all</u> participant codes from 2016 to 2017. Order the results using `Average Duration Time In Days` in descending order.
#
# <b>⚠️Hint: Think about the CASE Statement and how you might use this to help you with your classification! This is a more challenging question so you'll need to think through this step by step. You might also find `CTEs` or `Sub Queries` helpful for you.</b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
#
# WITH Avg_Duration_Table AS (
#     SELECT
#         Participant_Code,
#         Outage_Reason,
#         Year,
#         COUNT (EventID) AS Total_Number_Outage_Events,
#         ROUND (AVG(ABS(JULIANDAY(End_Time)-JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days
#     FROM
#         AEMR_Outage_Table
#     WHERE
#         Status = 'Approved'
#         AND YEAR BETWEEN 2016 AND 2017
#     GROUP BY
#         Participant_Code, Outage_Reason, Year
#     ORDER BY
#         Total_Number_Outage_Events DESC, Outage_Reason, Year
#     )
#
# SELECT *,
#      CASE WHEN Average_Outage_Duration_In_Days > 1 THEN 'High Risk'
#         WHEN Average_Outage_Duration_In_Days > 0.5 THEN 'Medium Risk'
#         ELSE 'Low Risk' END
#         AS Risk_Classification
# FROM Avg_Duration_Table;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07, 'Low Risk'),
#  ('GW', 'Forced', 2016, 317, 0.38, 'Low Risk'),
#  ('GW', 'Forced', 2017, 227, 1.06, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 208, 0.07, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 206, 0.08, 'Low Risk'),
#  ('MELK', 'Forced', 2017, 177, 2.28, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 172, 0.42, 'Low Risk'),
#  ('MELK', 'Forced', 2016, 157, 0.83, 'Medium Risk'),
#  ('PUG', 'Forced', 2017, 135, 0.25, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 120, 0.02, 'Low Risk'),
#  ('MELK', 'Scheduled (Planned)', 2016, 85, 4.61, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 81, 1.22, 'High Risk'),
#  ('KORL', 'Forced', 2017, 76, 1.21, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 72, 0.84, 'Medium Risk'),
#  ('MELK', 'Scheduled (Planned)', 2017, 70, 6.89, 'High Risk'),
#  ('PMC', 'Forced', 2016, 69, 0.49, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 65, 0.19, 'Low Risk'),
#  ('KORL', 'Forced', 2016, 53, 0.38, 'Low Risk'),
#  ('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89, 'High Risk'),
#  ('COLLGAR', 'Forced', 2017, 45, 1.38, 'High Risk'),
#  ('GW', 'Scheduled (Planned)', 2016, 45, 4.43, 'High Risk'),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45, 'High Risk'),
#  ('AURICON', 'Consequential', 2017, 42, 0.21, 'Low Risk'),
#  ('AURICON', 'Consequential', 2016, 41, 0.13, 'Low Risk'),
#  ('PMC', 'Forced', 2017, 40, 0.04, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 39, 0.24, 'Low Risk'),
#  ('PJRH', 'Scheduled (Planned)', 2016, 38, 2.37, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 37, 4.96, 'High Risk'),
#  ('PJRH', 'Scheduled (Planned)', 2017, 35, 2.61, 'High Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 30, 0.44, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2016, 29, 1.11, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 29, 4.85, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 28, 0.99, 'Medium Risk'),
#  ('PMC', 'Scheduled (Planned)', 2016, 27, 1.9, 'High Risk'),
#  ('GW', 'Scheduled (Planned)', 2017, 26, 2.65, 'High Risk'),
#  ('PUG', 'Forced', 2016, 24, 0.92, 'Medium Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 24, 0.71, 'Medium Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 23, 0.34, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.18, 'Low Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 23, 1.97, 'High Risk'),
#  ('ENRG', 'Forced', 2016, 21, 2.24, 'High Risk'),
#  ('GW', 'Consequential', 2016, 20, 0.18, 'Low Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 20, 0.31, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2016, 20, 6.96, 'High Risk'),
#  ('STHRNCRS', 'Forced', 2017, 18, 0.26, 'Low Risk'),
#  ('MUND', 'Scheduled (Planned)', 2016, 18, 3.53, 'High Risk'),
#  ('EUCT', 'Consequential', 2016, 17, 0.41, 'Low Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2017, 16, 0.65, 'Medium Risk'),
#  ('PUG', 'Scheduled (Planned)', 2016, 16, 1.47, 'High Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 16, 3.38, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 15, 0.57, 'Medium Risk'),
#  ('MUND', 'Forced', 2017, 15, 0.19, 'Low Risk'),
#  ('EUCT', 'Consequential', 2017, 14, 0.32, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 14, 0.22, 'Low Risk'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2017, 14, 0.68, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2016, 13, 0.33, 'Low Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.28, 'Low Risk'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 13, 0.62, 'Medium Risk'),
#  ('COLLGAR', 'Consequential', 2016, 12, 0.6, 'Medium Risk'),
#  ('DNHR', 'Consequential', 2017, 12, 0.24, 'Low Risk'),
#  ('MCG', 'Forced', 2017, 12, 0.28, 'Low Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 4.28, 'High Risk'),
#  ('PMC', 'Scheduled (Planned)', 2017, 12, 1.7, 'High Risk'),
#  ('DNHR', 'Consequential', 2016, 11, 0.28, 'Low Risk'),
#  ('EUCT', 'Forced', 2016, 11, 5.9, 'High Risk'),
#  ('PUG', 'Scheduled (Planned)', 2017, 11, 2.25, 'High Risk'),
#  ('PMC', 'Consequential', 2016, 10, 0.28, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.24, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2016, 9, 0.22, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 9, 0.21, 'Low Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 9, 6.36, 'High Risk'),
#  ('PMC', 'Consequential', 2017, 8, 3.52, 'High Risk'),
#  ('WGUTD', 'Forced', 2017, 8, 3.44, 'High Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.15, 'Low Risk'),
#  ('MELK', 'Consequential', 2016, 7, 0.76, 'Medium Risk'),
#  ('ENRG', 'Consequential', 2017, 7, 0.27, 'Low Risk'),
#  ('ENRG', 'Forced', 2017, 7, 0.26, 'Low Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 7, 0.21, 'Low Risk'),
#  ('MUND', 'Scheduled (Planned)', 2017, 7, 1.7, 'High Risk'),
#  ('WGUTD', 'Consequential', 2016, 6, 1.99, 'High Risk'),
#  ('KORL', 'Consequential', 2017, 6, 2.24, 'High Risk'),
#  ('COLLGAR', 'Consequential', 2017, 5, 0.23, 'Low Risk'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.33, 'Low Risk'),
#  ('TRMOS', 'Scheduled (Planned)', 2016, 5, 1.42, 'High Risk'),
#  ('GW', 'Consequential', 2017, 4, 0.24, 'Low Risk'),
#  ('MUND', 'Forced', 2016, 4, 0.37, 'Low Risk'),
#  ('TSLA_MGT', 'Forced', 2017, 4, 0.31, 'Low Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.47, 'Low Risk'),
#  ('TRMOS', 'Scheduled (Planned)', 2017, 4, 2.31, 'High Risk'),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06, 'Low Risk'),
#  ('EUCT', 'Forced', 2017, 3, 0.03, 'Low Risk'),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33, 'Low Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.24, 'Low Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.35, 'Low Risk'),
#  ('MCG', 'Consequential', 2016, 2, 0.26, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2017, 2, 0.26, 'Low Risk'),
#  ('MCG', 'Consequential', 2017, 2, 0.23, 'Low Risk'),
#  ('WGUTD', 'Forced', 2016, 2, 0.02, 'Low Risk'),
#  ('TSLA_MGT', 'Forced', 2016, 2, 0.25, 'Low Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.05, 'Low Risk'),
#  ('AUXC', 'Scheduled (Planned)', 2016, 2, 1.25, 'High Risk'),
#  ('AUXC', 'Consequential', 2016, 1, 0.96, 'Medium Risk'),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04, 'Low Risk'),
#  ('AUXC', 'Consequential', 2017, 1, 0.1, 'Low Risk'),
#  ('MCG', 'Forced', 2016, 1, 0.79, 'Medium Risk'),
#  ('DNHR', 'Forced', 2016, 1, 0.4, 'Low Risk'),
#  ('DNHR', 'Forced', 2017, 1, 0.48, 'Low Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.6, 'Medium Risk'),
#  ('TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.06, 'Low Risk'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.08, 'Low Risk'),
#  ('STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.06, 'Low Risk'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25, 'Low Risk'),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42, 'High Risk'),
#  ('WGUTD', 'Scheduled (Planned)', 2017, 1, 10.58, 'High Risk'),
#  ('AUXC', 'Scheduled (Planned)', 2017, 1, 2.88, 'High Risk')]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07, 'Low Risk'),
#  ('GW', 'Forced', 2016, 317, 0.38, 'Low Risk'),
#  ('GW', 'Forced', 2017, 227, 1.06, 'High Risk')]

# %% [markdown]
# Now that we've classified our participants as either `High Risk`, `Medium Risk` or `Low Risk`, we want to dig a little deeper.
#
# Does it make sense that `Consequential`, `Opportunistic` or `Planned` aren't considered regarding the Risk Category?
#
# Perhaps we should refine our category accordingly by ensuring we focus our Risk Category on labelling only `Forced` Outages as being a Risk. After all, Forced Outages are the unplanned outages that risk the security of the electricity grid.
#
# Let's add two additional criteria to our classification considering `Total Number of Outage Events` and `Outage Type`.
#
# We've summarised these below:
#
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day) OR the Total Number of Outage Events > 20 </li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours OR the Total Number of Outage Events is Between 10 and 20 </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours OR the Total Number of Outage Events < 10 </li>
# <li> If Outage Type is not forced, then N/A
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Five </h3>

# %% [markdown]
# <b> Just as you did in Question Four, Using the above criteria for context, write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> using the new classification criteria. Order the results using `Average Duration Time In Days` in descending order.
#
# <b>⚠️Hint: Think about the CASE Statement and how you might use this to help you with your classification! </b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
#
# WITH Avg_Duration_Table AS (
#     SELECT
#         Participant_Code,
#         Outage_Reason,
#         Year,
#         COUNT (EventID) AS Total_Number_Outage_Events,
#         ROUND (AVG(ABS(JULIANDAY(End_Time)-JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days
#     FROM
#         AEMR_Outage_Table
#     WHERE
#         Status = 'Approved'
#         AND YEAR BETWEEN 2016 AND 2017
#     GROUP BY
#         Participant_Code, Outage_Reason, Year
#     ORDER BY
#         Total_Number_Outage_Events DESC, Outage_Reason, Year
#     )
#
# SELECT *,
#      CASE WHEN Outage_Reason NOT LIKE 'Forced' THEN 'N/A'
#           WHEN Average_Outage_Duration_In_Days > 1
#              OR Total_Number_Outage_Events > 20 THEN 'High Risk'
#           WHEN Average_Outage_Duration_In_Days > 0.5
#              OR Total_Number_Outage_Events > 10 THEN 'Medium Risk'
#           ELSE 'Low Risk' END
#         AS Risk_Classification
# FROM Avg_Duration_Table
# ORDER BY Average_Outage_Duration_In_Days DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('WGUTD', 'Scheduled (Planned)', 2017, 1, 10.58, 'N/A'),
#  ('KORL', 'Scheduled (Planned)', 2016, 20, 6.96, 'N/A'),
#  ('MELK', 'Scheduled (Planned)', 2017, 70, 6.89, 'N/A'),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 9, 6.36, 'N/A'),
#  ('EUCT', 'Forced', 2016, 11, 5.9, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 37, 4.96, 'N/A'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 29, 4.85, 'N/A'),
#  ('MELK', 'Scheduled (Planned)', 2016, 85, 4.61, 'N/A'),
#  ('GW', 'Scheduled (Planned)', 2016, 45, 4.43, 'N/A'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 4.28, 'N/A'),
#  ('MUND', 'Scheduled (Planned)', 2016, 18, 3.53, 'N/A'),
#  ('PMC', 'Consequential', 2017, 8, 3.52, 'N/A'),
#  ('WGUTD', 'Forced', 2017, 8, 3.44, 'High Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 16, 3.38, 'N/A'),
#  ('AUXC', 'Scheduled (Planned)', 2017, 1, 2.88, 'N/A'),
#  ('GW', 'Scheduled (Planned)', 2017, 26, 2.65, 'N/A'),
#  ('PJRH', 'Scheduled (Planned)', 2017, 35, 2.61, 'N/A'),
#  ('PJRH', 'Scheduled (Planned)', 2016, 38, 2.37, 'N/A'),
#  ('TRMOS', 'Scheduled (Planned)', 2017, 4, 2.31, 'N/A'),
#  ('MELK', 'Forced', 2017, 177, 2.28, 'High Risk'),
#  ('PUG', 'Scheduled (Planned)', 2017, 11, 2.25, 'N/A'),
#  ('ENRG', 'Forced', 2016, 21, 2.24, 'High Risk'),
#  ('KORL', 'Consequential', 2017, 6, 2.24, 'N/A'),
#  ('WGUTD', 'Consequential', 2016, 6, 1.99, 'N/A'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 23, 1.97, 'N/A'),
#  ('PMC', 'Scheduled (Planned)', 2016, 27, 1.9, 'N/A'),
#  ('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89, 'N/A'),
#  ('PMC', 'Scheduled (Planned)', 2017, 12, 1.7, 'N/A'),
#  ('MUND', 'Scheduled (Planned)', 2017, 7, 1.7, 'N/A'),
#  ('PUG', 'Scheduled (Planned)', 2016, 16, 1.47, 'N/A'),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45, 'N/A'),
#  ('TRMOS', 'Scheduled (Planned)', 2016, 5, 1.42, 'N/A'),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42, 'N/A'),
#  ('COLLGAR', 'Forced', 2017, 45, 1.38, 'High Risk'),
#  ('AUXC', 'Scheduled (Planned)', 2016, 2, 1.25, 'N/A'),
#  ('PJRH', 'Forced', 2016, 81, 1.22, 'High Risk'),
#  ('KORL', 'Forced', 2017, 76, 1.21, 'High Risk'),
#  ('COLLGAR', 'Forced', 2016, 29, 1.11, 'High Risk'),
#  ('GW', 'Forced', 2017, 227, 1.06, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 28, 0.99, 'N/A'),
#  ('AUXC', 'Consequential', 2016, 1, 0.96, 'N/A'),
#  ('PUG', 'Forced', 2016, 24, 0.92, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 72, 0.84, 'High Risk'),
#  ('MELK', 'Forced', 2016, 157, 0.83, 'High Risk'),
#  ('MCG', 'Forced', 2016, 1, 0.79, 'Medium Risk'),
#  ('MELK', 'Consequential', 2016, 7, 0.76, 'N/A'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 24, 0.71, 'N/A'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2017, 14, 0.68, 'N/A'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2017, 16, 0.65, 'N/A'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 13, 0.62, 'N/A'),
#  ('COLLGAR', 'Consequential', 2016, 12, 0.6, 'N/A'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.6, 'N/A'),
#  ('ENRG', 'Consequential', 2016, 15, 0.57, 'N/A'),
#  ('PMC', 'Forced', 2016, 69, 0.49, 'High Risk'),
#  ('DNHR', 'Forced', 2017, 1, 0.48, 'Low Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.47, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2016, 30, 0.44, 'N/A'),
#  ('TRMOS', 'Forced', 2017, 172, 0.42, 'High Risk'),
#  ('EUCT', 'Consequential', 2016, 17, 0.41, 'N/A'),
#  ('DNHR', 'Forced', 2016, 1, 0.4, 'Low Risk'),
#  ('GW', 'Forced', 2016, 317, 0.38, 'High Risk'),
#  ('KORL', 'Forced', 2016, 53, 0.38, 'High Risk'),
#  ('MUND', 'Forced', 2016, 4, 0.37, 'Low Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.35, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2017, 23, 0.34, 'N/A'),
#  ('STHRNCRS', 'Forced', 2016, 13, 0.33, 'Medium Risk'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.33, 'N/A'),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33, 'N/A'),
#  ('EUCT', 'Consequential', 2017, 14, 0.32, 'N/A'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 20, 0.31, 'N/A'),
#  ('TSLA_MGT', 'Forced', 2017, 4, 0.31, 'Low Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.28, 'N/A'),
#  ('MCG', 'Forced', 2017, 12, 0.28, 'Medium Risk'),
#  ('DNHR', 'Consequential', 2016, 11, 0.28, 'N/A'),
#  ('PMC', 'Consequential', 2016, 10, 0.28, 'N/A'),
#  ('ENRG', 'Consequential', 2017, 7, 0.27, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 18, 0.26, 'Medium Risk'),
#  ('ENRG', 'Forced', 2017, 7, 0.26, 'Low Risk'),
#  ('MCG', 'Consequential', 2016, 2, 0.26, 'N/A'),
#  ('STHRNCRS', 'Consequential', 2017, 2, 0.26, 'N/A'),
#  ('PUG', 'Forced', 2017, 135, 0.25, 'High Risk'),
#  ('TSLA_MGT', 'Forced', 2016, 2, 0.25, 'Low Risk'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25, 'N/A'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 39, 0.24, 'N/A'),
#  ('DNHR', 'Consequential', 2017, 12, 0.24, 'N/A'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.24, 'N/A'),
#  ('GW', 'Consequential', 2017, 4, 0.24, 'N/A'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.24, 'N/A'),
#  ('COLLGAR', 'Consequential', 2017, 5, 0.23, 'N/A'),
#  ('MCG', 'Consequential', 2017, 2, 0.23, 'N/A'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 14, 0.22, 'N/A'),
#  ('STHRNCRS', 'Consequential', 2016, 9, 0.22, 'N/A'),
#  ('AURICON', 'Consequential', 2017, 42, 0.21, 'N/A'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 9, 0.21, 'N/A'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 7, 0.21, 'N/A'),
#  ('TRMOS', 'Forced', 2016, 65, 0.19, 'High Risk'),
#  ('MUND', 'Forced', 2017, 15, 0.19, 'Medium Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.18, 'N/A'),
#  ('GW', 'Consequential', 2016, 20, 0.18, 'N/A'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.15, 'N/A'),
#  ('AURICON', 'Consequential', 2016, 41, 0.13, 'N/A'),
#  ('AUXC', 'Consequential', 2017, 1, 0.1, 'N/A'),
#  ('AUXC', 'Forced', 2016, 206, 0.08, 'High Risk'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.08, 'N/A'),
#  ('AURICON', 'Forced', 2017, 490, 0.07, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 208, 0.07, 'High Risk'),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06, 'N/A'),
#  ('TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.06, 'N/A'),
#  ('STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.06, 'N/A'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.05, 'N/A'),
#  ('PMC', 'Forced', 2017, 40, 0.04, 'High Risk'),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04, 'N/A'),
#  ('EUCT', 'Forced', 2017, 3, 0.03, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 120, 0.02, 'High Risk'),
#  ('WGUTD', 'Forced', 2016, 2, 0.02, 'Low Risk')]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89, 'N/A'),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45, 'N/A'),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33, 'N/A')]

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part II. Energy Losses & Market Reliability ⚡ </h3>

# %% [markdown]
# When an energy provider provides energy to the market, they are making a commitment to the market and saying; “We will supply X amount of energy to the market under a contractual obligation.” However, in a situation where the outages are Forced, the energy provider intended to provide energy but are unable to provide energy and are forced offline. <b style="color:Maroon">If many energy providers are forced offline at the same time it could cause an energy security risk that AEMR needs to mitigate. </b>
#
# To ensure this doesn’t happen, the AEMR is interested in exploring the following questions:
#
# <li> Of the outage types in 2016 and 2017, what percent were Forced Outage(s)?
# <li> What was the average duration for a forced outage during both 2016 and 2017? Have we seen an increase in the average duration of forced outages?
# <li> Which energy providers tended to have the largest number of forced outages?
#
# <p>
#
# <b> We'll examine this in the questions below. </b>
#
# <img src = "https://media.istockphoto.com/id/1281821795/photo/market-stock-graph-and-information-with-city-light-and-electricity-and-energy-facility-banner.jpg?s=612x612&w=0&k=20&c=RSN5LqeMW28HW10aA190_DWR5YJ5tG2wixHFPBV3uZE=">

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Six </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the proportion of Forced Outages that have occurred over the 2016 - 2017 Period.
# Do we observe any particular increases regarding any Outage Types over this period? </b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
#
# WITH Outages_And_Forced_Outages AS (
#     SELECT Year,
#         COUNT (EventID) AS Total_Number_Outages,
#         (SELECT COUNT (Outage_Reason)
#         FROM AEMR_Outage_Table
#         WHERE Outage_Reason = 'Forced'
#         AND Year = T.Year
#         AND Status = 'Approved'
#         GROUP BY Year) AS Total_Number_Forced_Outage_Events
#     FROM AEMR_Outage_Table AS T
#     WHERE Status = 'Approved'
#         AND YEAR BETWEEN 2016 AND 2017
#     GROUP BY Year
#     )
#
# SELECT *,
#     ROUND ((Total_Number_Forced_Outage_Events * 1.0) / Total_Number_Outages,4) * 100 AS Pct_Outage_Forced
# FROM Outages_And_Forced_Outages;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1931, 1264, 65.46), (2017, 2171, 1622, 74.71)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(1931, 1264, 65.46), (2171, 1622, 74.71)]

# %% [markdown]
# Great. It's clear to see now that `Forced Outages` are problematic for us. Not only are they the only outage type that generates financial losses as the Outage is unplanned, it seems there is a number of Energy Participants who have been having a significantly high number of Outages.
#
# Now what can we do about this?
#
# Let's break our analysis down into Macro and Micro Analysis.
# The total gives us the Overall Duration a participant is offline / has lost energy, however, it doesn't tell us how *frequently* this occurs. In other words, if we have one or two very big outages, it might contribute to very large totals.
#
# However, perhaps an <b> average </b> can help us identify how big these Outages might really be, spread across the year!
#
# Let's take a look.

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Seven </h3>

# %% [markdown]
# Write a SQL Statement to calculate the `Total Number of Outages`, `Total Duration In Days`and `Total Energy Lost` of all valid `Outages` for each `participant code` and `facility_code`, sorted by `Total Energy Lost` in descending order and Ordered by the YEAR Category.

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
#
# SELECT
#     COUNT (EventID) AS Total_Number_Outages,
#     ROUND (SUM(ABS(JULIANDAY(End_Time)-JULIANDAY(Start_Time))),2) AS Total_Duration_In_Days,
#     ROUND (SUM (Energy_Lost_MW),2) AS Total_Energy_Lost,
#     Outage_Reason,
#     Participant_Code,
#     Facility_Code,
#     Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
#     AND Year BETWEEN 2016 AND 2017
# GROUP BY Outage_Reason, Participant_Code, Facility_Code,Year
# ORDER BY Total_Duration_In_Days DESC, Year DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(70, 482.58, 7499.28, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2017),
#  (177, 404.15, 10285.4, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (85, 392.25, 9668.79, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2016),
#  (227, 240.69, 19326.56, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (45, 199.4, 6450.0, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (37, 183.58, 516.92, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (29, 140.6, 445.6, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (20, 139.25, 1685.6, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (157, 129.6, 13771.07, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (317, 120.6, 15751.38, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (81, 98.79, 5881.52, 'Forced', 'PJRH', 'PJRH_GT11', 2016),
#  (76, 91.79, 4679.68, 'Forced', 'KORL', 'KORL_GT3', 2017),
#  (35, 91.35, 2110.01, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (38, 89.9, 2445.0, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (46, 87.02, 6964.8, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (172, 71.9, 5016.67, 'Forced', 'TRMOS', 'TIWEST_COG1', 2017),
#  (26, 68.9, 3812.42, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (45, 65.4, 5941.25, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (11, 64.9, 64.8, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (18, 63.46, 664.0, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (45, 62.1, 2787.06, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (72, 60.13, 4839.28, 'Forced', 'PJRH', 'PJRH_GT11', 2017),
#  (9, 57.27, 1632.78, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (16, 54.1, 1326.6, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (27, 51.4, 4839.0, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2016),
#  (12, 51.38, 2139.87, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (21, 47.04, 1182.8, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (23, 45.25, 448.8, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (69, 34.06, 9093.09, 'Forced', 'PMC', 'PMC_AG', 2016),
#  (490, 33.65, 21639.55, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (135, 33.4, 4112.1, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (29, 32.33, 4320.86, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (8, 28.15, 1672.66, 'Consequential', 'PMC', 'PMC_AG', 2017),
#  (28, 27.75, 678.4, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (8, 27.54, 221.29, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (11, 24.73, 1160.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (16, 23.56, 1334.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (24, 22.17, 815.47, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (12, 20.35, 1639.2, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2017),
#  (53, 20.0, 4040.32, 'Forced', 'KORL', 'KORL_GT3', 2016),
#  (24, 17.0, 2877.04, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2016),
#  (206, 16.04, 2734.14, 'Forced', 'AUXC', 'AUXC_WGP', 2016),
#  (208, 15.06, 10696.28, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (6, 13.42, 505.95, 'Consequential', 'KORL', 'KORL_GT3', 2017),
#  (30, 13.21, 297.0, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (65, 12.63, 1232.43, 'Forced', 'TRMOS', 'TIWEST_COG1', 2016),
#  (6, 11.96, 198.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (7, 11.9, 262.46, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (1, 10.58, 36.0, 'Scheduled (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (16, 10.44, 1339.7, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2017),
#  (14, 9.46, 322.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (4, 9.23, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2017),
#  (39, 9.17, 3100.95, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (42, 8.88, 2553.24, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (15, 8.48, 161.4, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (13, 8.04, 299.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (23, 7.73, 227.7, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (12, 7.15, 1374.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (5, 7.08, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (17, 6.96, 290.4, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2016),
#  (20, 6.21, 2951.0, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (7, 5.35, 1524.82, 'Consequential', 'MELK', 'MELK_G7', 2016),
#  (41, 5.31, 3925.55, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (18, 4.65, 292.7, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (14, 4.52, 222.3, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2017),
#  (13, 4.29, 299.0, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (23, 4.21, 2178.95, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (13, 3.67, 1423.53, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (20, 3.6, 832.72, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (12, 3.4, 563.33, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (11, 3.12, 15.84, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (14, 3.04, 1172.05, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (12, 2.9, 17.28, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (1, 2.88, 26.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2017),
#  (15, 2.85, 398.58, 'Forced', 'MUND', 'MUNDARING_GT1', 2017),
#  (10, 2.81, 643.0, 'Consequential', 'PMC', 'PMC_AG', 2016),
#  (2, 2.5, 50.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2016),
#  (10, 2.42, 842.8, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (120, 2.1, 1768.76, 'Forced', 'AUXC', 'AUXC_WGP', 2017),
#  (9, 1.94, 207.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (9, 1.9, 335.86, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (4, 1.9, 87.0, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (7, 1.87, 63.8, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (7, 1.85, 191.86, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (5, 1.65, 763.96, 'Opportunistic Maintenance (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (40, 1.56, 5648.44, 'Forced', 'PMC', 'PMC_AG', 2017),
#  (4, 1.48, 147.2, 'Forced', 'MUND', 'MUNDARING_GT1', 2016),
#  (7, 1.48, 580.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (1, 1.42, 55.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (4, 1.23, 169.9, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (8, 1.21, 248.0, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (5, 1.17, 926.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (3, 1.04, 24.1, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (3, 0.98, 523.0, 'Opportunistic Maintenance (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (4, 0.96, 89.29, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (1, 0.96, 25.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2016),
#  (1, 0.79, 55.0, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (3, 0.71, 348.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (1, 0.6, 36.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (2, 0.52, 46.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (2, 0.52, 110.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (2, 0.5, 160.0, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (1, 0.48, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (2, 0.46, 94.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (1, 0.4, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (1, 0.25, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2017),
#  (4, 0.23, 220.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (1, 0.1, 26.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2017),
#  (3, 0.1, 64.8, 'Forced', 'EUCT', 'GRASMERE_WF1', 2017),
#  (2, 0.1, 72.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (1, 0.08, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2016),
#  (1, 0.06, 23.0, 'Opportunistic Maintenance (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (1, 0.06, 0.0, 'Opportunistic Maintenance (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (1, 0.04, 36.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (2, 0.04, 54.0, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(70, 482.58, 7499.28, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2017),
#  (177, 404.15, 10285.4, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (85, 392.25, 9668.79, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2016),
#  (227, 240.69, 19326.56, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (45, 199.4, 6450.0, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Eight </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the `Average Duration In Days`and `Average Energy Lost` of all valid `FORCED OUTAGES` for each `participant code` and `facility_code` sorted by `Average Energy Lost` in descending order and Ordered by the YEAR Category.

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
#
# SELECT
#     ROUND (AVG(ABS(JULIANDAY(End_Time)-JULIANDAY(Start_Time))),2) AS Avg_Duration_In_Days,
#     ROUND (AVG(Energy_Lost_MW),2) AS Avg_Energy_Lost,
#     Outage_Reason,
#     Participant_Code,
#     Facility_Code,
#     Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
#     AND Outage_Reason = 'Forced'
# GROUP BY Outage_Reason, Participant_Code, Facility_Code, Year
# ORDER BY Avg_Duration_In_Days DESC, Year;
# Out:
#  * sqlite:///AEMR.db
# (sqlite3.OperationalError) near "Q8": syntax error
# [SQL: Q8
# SELECT
#     ROUND (AVG(ABS(JULIANDAY(End_Time)-JULIANDAY(Start_Time))),2) AS Avg_Duration_In_Days,
#     ROUND (AVG(Energy_Lost_MW),2) AS Avg_Energy_Lost,
#     Outage_Reason,
#     Participant_Code,
#     Facility_Code,
#     Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
#     AND Outage_Reason = 'Forced'
# GROUP BY Outage_Reason, Participant_Code, Facility_Code, Year
# ORDER BY Avg_Duration_In_Days DESC, Year;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import pandas as pd
dataframe = pd.DataFrame(Q8,columns = ['Avg_Duration_In_Days','Avg_Energy_Lost','Participant_Code','Facility_Code','Year'])
dataframe.to_csv("Q8.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 import pandas as pd
# ----> 2 dataframe = pd.DataFrame(Q8,columns = ['Avg_Duration_In_Days','Avg_Energy_Lost','Participant_Code','Facility_Code','Year'])
#       3 dataframe.to_csv("Q8.csv")
#
# NameError: name 'Q8' is not defined

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(5.9, 5.89, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (3.44, 27.66, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (2.28, 58.11, 'Forced', 'MELK', 'MELK_G7', 2017)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Nine </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the `Average Energy Lost` and `Total Energy Lost` for each `Facility Code` and `Participant Code` across both the 2016 and 2017 periods when the `Outage_Reason` is set to Forced. Upon completion of this, calculate the <u> percentage </u> of energy lost due to forced outages for each `Facility_Code`. Please ORDER the query by `Total Energy Lost` from 2016 to 2017.
#
# From your analysis, which participants have contributed the most to the Energy Lost due to Forced Outages?

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
#
#     SELECT
#         ROUND (AVG(Energy_Lost_MW),2) AS Avg_Energy_Lost,
#         ROUND (SUM (Energy_Lost_MW),2) AS Total_Energy_Lost,
#         ROUND ((SUM(Energy_Lost_MW * 1.0) / (SELECT SUM(Energy_Lost_MW)
#                                              FROM AEMR_Outage_Table
#                                              WHERE Status = 'Approved'
#                                              AND Outage_Reason = 'Forced') ),4) * 100 AS Pct_Energy_Loss,
#         Description_of_Outage,
#         Participant_Code,
#         Facility_Code,
#         Year,
#         Month
#     FROM AEMR_Outage_Table
#     WHERE Status = 'Approved'
#         AND Outage_Reason = 'Forced'
#         AND Year BETWEEN 2016 AND 2017
#     GROUP BY Outage_Reason,Participant_Code,Facility_Code,Year,Month
#     ORDER BY Total_Energy_Lost DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(77.31, 7267.33, 4.77, 'Under generation - ambient conditions', 'AURICON', 'AURICON_PNJ_U1', 2017, 12),
#  (89.3, 5983.3, 3.93, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 7),
#  (44.82, 4571.23, 3.0, 'FO', 'GW', 'BW1_GREENWATERS_G2', 2016, 8),
#  (119.48, 3345.41, 2.1999999999999997, 'Deviation during ramp up from outage', 'AURICON', 'AURICON_PNJ_U1', 2017, 8),
#  (123.2, 3203.25, 2.1, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2016, 2),
#  (109.1, 2945.82, 1.9300000000000002, 'GT1 went unavailable due to Fire System fault.', 'GW', 'BW1_GREENWATERS_G2', 2016, 11),
#  (189.9, 2848.5, 1.87, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2016, 1),
#  (56.3, 2758.92, 1.81, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2016, 3),
#  (56.55, 2657.86, 1.7500000000000002, ' Gt2 Fire panel fault', 'GW', 'BW1_GREENWATERS_G2', 2017, 8),
#  (90.51, 2262.86, 1.49, 'ID fan bearing failure - output reduced to 160MW (pro-rata)', 'MELK', 'MELK_G7', 2016, 9),
#  (122.24, 2200.27, 1.44, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 3),
#  (108.51, 2061.6, 1.35, 'GT1 Main Step Transformer temperature transducer lost signal making the TX unavailable.', 'GW', 'BW1_GREENWATERS_G2', 2017, 4),
#  (62.73, 2007.46, 1.32, 'unit maximum output was restricted to 100 MW as-generated due to high rotor temperature alarm for safety purposes', 'AURICON', 'AURICON_PNJ_U1', 2017, 2),
#  (19.17, 1974.73, 1.3, 'Deviation after unit trip', 'AURICON', 'AURICON_PNJ_U1', 2017, 10),
#  (134.54, 1749.0, 1.15, 'FO due to unit trip', 'GW', 'BW1_GREENWATERS_G2', 2017, 6),
#  (109.19, 1746.98, 1.15, 'Unit slow to ramp up.', 'AURICON', 'AURICON_PNJ_U1', 2016, 7),
#  (68.54, 1713.54, 1.13, 'loss of a cooling tower fan', 'MELK', 'MELK_G7', 2016, 10),
#  (106.03, 1696.45, 1.11, 'Over speed bolt test unsuccessful  ', 'MELK', 'MELK_G7', 2016, 1),
#  (237.06, 1659.42, 1.09, 'Full forced outage for RAH repairs (pro-rata)', 'MELK', 'MELK_G7', 2016, 6),
#  (138.24, 1658.82, 1.09, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 2),
#  (73.13, 1608.93, 1.06, 'Boiler feedpump capacity', 'MELK', 'MELK_G7', 2017, 12),
#  (20.09, 1607.41, 1.06, "Unit's output was constrained due to ventilation fan issues.", 'AURICON', 'AURICON_PNJ_U1', 2017, 6),
#  (83.19, 1580.53, 1.04, 'FO', 'KORL', 'KORL_GT3', 2016, 1),
#  (59.89, 1557.04, 1.02, 'Load Limitation', 'MELK', 'MELK_G7', 2016, 2),
#  (191.05, 1528.4, 1.0, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2017, 12),
#  (167.01, 1503.12, 0.9900000000000001, 'WGP U2 not started due to uneconomic short run.', 'AURICON', 'AURICON_PNJ_U1', 2016, 9),
#  (66.85, 1470.71, 0.97, 'Pro-rata forced outage delay in return to service', 'MELK', 'MELK_G7', 2017, 9),
#  (122.03, 1464.37, 0.96, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2017, 6),
#  (80.8, 1373.6, 0.8999999999999999, 'Additional DI instructed within interval when unit was already ramping. Unable to comply.', 'MELK', 'MELK_G7', 2016, 4),
#  (36.21, 1339.62, 0.88, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2016, 6),
#  (130.64, 1306.38, 0.86, 'Load restriction', 'MELK', 'MELK_G7', 2016, 12),
#  (26.59, 1303.02, 0.86, 'Plant failed to reach target due to operational issue.', 'AURICON', 'AURICON_PNJ_U1', 2017, 11),
#  (143.93, 1295.41, 0.8500000000000001, 'Boiler Maintenance', 'MELK', 'MELK_G7', 2017, 1),
#  (57.22, 1258.91, 0.83, 'Delayed ramp-up to target', 'AURICON', 'AURICON_PNJ_U1', 2016, 6),
#  (45.02, 1215.55, 0.8, 'Deviation from commissioning test plan. Contractor tuning requirement\n', 'AURICON', 'AURICON_PNJ_U1', 2016, 1),
#  (37.76, 1208.39, 0.79, 'forced outage due to unit trip', 'MELK', 'MELK_G7', 2017, 8),
#  (68.73, 1168.37, 0.77, 'Delay in unit ramp-up', 'AURICON', 'AURICON_PNJ_U1', 2017, 4),
#  (48.63, 1167.02, 0.77, 'ID fan capacity', 'MELK', 'MELK_G7', 2017, 10),
#  (54.52, 1144.93, 0.75, 'FO', 'PJRH', 'PJRH_GT11', 2016, 7),
#  (186.3, 1117.77, 0.73, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2016, 9),
#  (151.81, 1062.69, 0.7000000000000001, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2017, 4),
#  (19.23, 1057.5, 0.69, 'Unit slow to ramp from previous setpoint', 'AURICON', 'AURICON_PNJ_U1', 2016, 11),
#  (33.01, 1056.47, 0.69, 'Deviation from dispatch', 'TRMOS', 'TIWEST_COG1', 2017, 10),
#  (150.86, 1056.0, 0.69, 'Unit Trip on start up.', 'COLLGAR', 'COLLGAR_WF1', 2016, 2),
#  (53.1, 1008.85, 0.66, 'No crane available Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 'GW', 'BW1_GREENWATERS_G2', 2016, 4),
#  (143.85, 1006.96, 0.66, 'Cable Termination Failures  ', 'COLLGAR', 'COLLGAR_WF1', 2016, 10),
#  (100.26, 1002.62, 0.66, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 5),
#  (82.34, 988.13, 0.65, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 1),
#  (59.81, 956.9, 0.63, 'FO', 'PJRH', 'PJRH_GT11', 2016, 5),
#  (94.63, 946.29, 0.62, 'FO', 'PJRH', 'PJRH_GT11', 2017, 2),
#  (83.98, 923.83, 0.61, 'FO', 'PJRH', 'PJRH_GT11', 2016, 1),
#  (65.09, 911.27, 0.6, 'Evaporative cooler pump issues\n', 'AURICON', 'AURICON_PNJ_U1', 2016, 8),
#  (39.61, 911.02, 0.6, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2016, 9),
#  (179.6, 897.98, 0.59, 'delayed synchronization due to failure of fuel drain valve close limit switch', 'AURICON', 'AURICON_PNJ_U1', 2016, 4),
#  (88.01, 880.06, 0.58, 'Load reduction', 'MELK', 'MELK_G7', 2016, 3),
#  (65.03, 845.36, 0.5599999999999999, 'FO ', 'PJRH', 'PJRH_GT11', 2017, 11),
#  (27.97, 839.0, 0.5499999999999999, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 7),
#  (206.5, 826.0, 0.54, 'Western Power?s SCADA System Commissioning', 'COLLGAR', 'COLLGAR_WF1', 2016, 5),
#  (117.14, 820.0, 0.54, 'Forced reduction of load', 'COLLGAR', 'COLLGAR_WF1', 2017, 3),
#  (270.21, 810.62, 0.53, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2017, 8),
#  (201.01, 804.05, 0.53, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2016, 3),
#  (32.77, 786.37, 0.52, 'unit slow to ramp up.', 'AURICON', 'AURICON_PNJ_U1', 2017, 1),
#  (70.65, 777.19, 0.51, 'FO', 'PJRH', 'PJRH_GT11', 2017, 6),
#  (26.71, 774.67, 0.51, 'Deviation from resource plan', 'TRMOS', 'TIWEST_COG1', 2017, 11),
#  (76.64, 766.43, 0.5, 'Turbine vibrations', 'MELK', 'MELK_G7', 2017, 11),
#  (47.08, 753.28, 0.49, 'slow to ramp up ', 'AURICON', 'AURICON_PNJ_U1', 2016, 10),
#  (125.24, 751.42, 0.49, 'MFT / MTR', 'MELK', 'MELK_G7', 2017, 2),
#  (53.35, 746.93, 0.49, 'Partial forced outage', 'KORL', 'KORL_GT3', 2017, 11),
#  (63.86, 702.49, 0.45999999999999996, 'Gas Regulation issue', 'GW', 'BW1_GREENWATERS_G2', 2016, 2),
#  (46.75, 701.32, 0.45999999999999996, 'FO', 'PJRH', 'PJRH_GT11', 2017, 9),
#  (35.66, 677.5, 0.44, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 9),
#  (33.55, 671.05, 0.44, 'Deviation from dispatch', 'TRMOS', 'TIWEST_COG1', 2017, 7),
#  (34.79, 661.04, 0.43, 'PNJ U1 max output reduced due to ambient conditions.', 'AURICON', 'AURICON_PNJ_U1', 2017, 7),
#  (28.68, 659.72, 0.43, 'Output limited due to ambient condition.', 'AURICON', 'AURICON_PNJ_U1', 2017, 5),
#  (64.59, 645.92, 0.42, 'Forced outage due to a high vibration alert on power turbine', 'KORL', 'KORL_GT3', 2017, 12),
#  (105.33, 632.0, 0.41000000000000003, 'FO', 'PJRH', 'PJRH_GT11', 2016, 11),
#  (31.2, 624.08, 0.41000000000000003, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2016, 5),
#  (87.82, 614.76, 0.4, 'FO', 'KORL', 'KORL_GT3', 2016, 11),
#  (55.81, 613.95, 0.4, 'FO', 'KORL', 'KORL_GT3', 2017, 8),
#  (45.68, 593.81, 0.38999999999999996, 'Mill A and Mill C starting faults', 'MELK', 'MELK_G7', 2017, 5),
#  (32.65, 587.71, 0.38999999999999996, 'Unit slow to ramp up. ', 'AURICON', 'AURICON_PNJ_U1', 2017, 9),
#  (73.36, 586.9, 0.38999999999999996, 'FO', 'KORL', 'KORL_GT3', 2017, 6),
#  (109.12, 545.59, 0.36, 'Fuel valves issue', 'AURICON', 'AURICON_PNJ_U1', 2016, 12),
#  (33.68, 538.82, 0.35000000000000003, 'Deviation from dispatch', 'TRMOS', 'TIWEST_COG1', 2017, 9),
#  (179.3, 537.9, 0.35000000000000003, 'Delayed RTS', 'MELK', 'MELK_G7', 2016, 5),
#  (53.36, 533.6, 0.35000000000000003, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 12),
#  (14.01, 532.2, 0.35000000000000003, 'power steam imbalance\n', 'AUXC', 'AUXC_WGP', 2016, 2),
#  (177.33, 532.0, 0.35000000000000003, 'Refer to Dispatch Advisory 16868', 'COLLGAR', 'COLLGAR_WF1', 2016, 11),
#  (173.33, 520.0, 0.33999999999999997, 'Steam Turbine trip', 'COLLGAR', 'COLLGAR_WF1', 2016, 9),
#  (73.69, 515.86, 0.33999999999999997, 'FO', 'PJRH', 'PJRH_GT11', 2016, 6),
#  (84.96, 509.78, 0.33, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2016, 4),
#  (16.4, 508.43, 0.33, 'Refinery Issues - Steam/Power Imbalance', 'AUXC', 'AUXC_WGP', 2017, 12),
#  (62.92, 503.36, 0.33, 'Condenser and cooling tower performance', 'MELK', 'MELK_G7', 2017, 6),
#  (47.97, 479.65, 0.31, 'FO', 'KORL', 'KORL_GT3', 2017, 9),
#  (31.9, 478.56, 0.31, 'Deviation from dispatch', 'TRMOS', 'TIWEST_COG1', 2017, 8),
#  (118.75, 475.0, 0.31, 'FO', 'PJRH', 'PJRH_GT11', 2016, 12),
#  (117.75, 471.0, 0.31, 'FO', 'PJRH', 'PJRH_GT11', 2016, 4),
#  (22.41, 470.57, 0.31, 'Condenser and cooling tower performance', 'MELK', 'MELK_G7', 2017, 7),
#  (24.24, 460.5, 0.3, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 8),
#  (41.45, 455.96, 0.3, 'Loss of a mill', 'MELK', 'MELK_G7', 2016, 11),
#  (112.93, 451.73, 0.3, 'GT Power Oil Changeover', 'COLLGAR', 'COLLGAR_WF1', 2017, 6),
#  (44.94, 449.35, 0.3, 'Issue with oil guns', 'MELK', 'MELK_G7', 2017, 4),
#  (63.58, 445.06, 0.29, 'FO', 'KORL', 'KORL_GT3', 2017, 7),
#  (49.34, 444.1, 0.29, 'GT2A gas control valve actuator failed and required replacement.', 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 11),
#  (16.13, 435.43, 0.29, 'Slow to ramp up.', 'AURICON', 'AURICON_PNJ_U1', 2016, 2),
#  (33.14, 430.77, 0.27999999999999997, 'Deviation from dispatch', 'TRMOS', 'TIWEST_COG1', 2017, 6),
#  (30.27, 423.73, 0.27999999999999997, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2016, 7),
#  (16.25, 422.39, 0.27999999999999997, 'Refinery Issues - Steam/Power Imbalance', 'AUXC', 'AUXC_WGP', 2016, 1),
#  (59.71, 417.96, 0.27, 'CG 8/9 - WTG063 RMU SF6 Gas Top Up', 'COLLGAR', 'COLLGAR_WF1', 2017, 5),
#  (203.01, 406.03, 0.27, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2017, 9),
#  (39.86, 398.65, 0.26, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 9),
#  (64.25, 385.49, 0.25, 'Gas supplier constraint', 'PMC', 'PMC_AG', 2016, 5),
#  (19.21, 384.25, 0.25, 'Deviation from resource plan', 'TRMOS', 'TIWEST_COG1', 2017, 12),
#  (75.52, 377.59, 0.25, 'FO', 'PJRH', 'PJRH_GT11', 2017, 3),
#  (75.06, 375.3, 0.25, 'FO', 'KORL', 'KORL_GT3', 2017, 2),
#  (74.92, 374.6, 0.25, 'FO', 'KORL', 'KORL_GT3', 2016, 4),
#  (46.18, 369.4, 0.24, 'Delayed RTS due to operational issues', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 12),
#  (51.23, 358.58, 0.24, 'Forced Outage - BS on Overhead line pole S-81 - CG10/11', 'COLLGAR', 'COLLGAR_WF1', 2017, 12),
#  (57.96, 347.75, 0.22999999999999998, 'GT1 fire protection panel instrument fault ', 'GW', 'BW1_GREENWATERS_G2', 2017, 11),
#  (12.22, 342.12, 0.22, 'Low refinery steam demand, steam power imbalance', 'AUXC', 'AUXC_WGP', 2016, 5),
#  (33.74, 337.4, 0.22, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 10),
#  (83.33, 333.3, 0.22, 'FO', 'KORL', 'KORL_GT3', 2016, 3),
#  (46.43, 325.0, 0.21, 'FO', 'MCG', 'MWF_MUMBIDA_WF1', 2017, 8),
#  (35.51, 319.61, 0.21, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2016, 1),
#  (59.84, 299.2, 0.2, 'FO', 'KORL', 'KORL_GT3', 2016, 2),
#  (49.45, 296.7, 0.19, 'delayed ramping due to ticking water valve that delayed the start of the power augmentation system', 'AURICON', 'AURICON_PNJ_U1', 2016, 5),
#  (14.0, 293.97, 0.19, 'Power/ Steam Imbalance', 'AUXC', 'AUXC_WGP', 2016, 4),
#  (72.8, 291.2, 0.19, 'FO', 'KORL', 'KORL_GT3', 2017, 5),
#  (93.76, 281.29, 0.18, 'FO', 'PJRH', 'PJRH_GT11', 2017, 4),
#  (92.33, 277.0, 0.18, 'FO', 'PJRH', 'PJRH_GT11', 2016, 3),
#  (15.39, 277.0, 0.18, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 5),
#  (90.33, 270.99, 0.18, 'Unit issues ramping up to dispatch target due to safety concern when high rotor temperature alarm got activated', 'AURICON', 'AURICON_PNJ_U1', 2017, 3),
#  (13.47, 255.85, 0.16999999999999998, 'Refinery issues power/ steam imbalance\n', 'AUXC', 'AUXC_WGP', 2017, 2),
#  (49.8, 249.0, 0.16, 'FO', 'PJRH', 'PJRH_GT11', 2016, 8),
#  (20.72, 248.68, 0.16, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 10),
#  (61.75, 247.0, 0.16, 'Comms Upgrade cause unplanned pausing of turbines', 'COLLGAR', 'COLLGAR_WF1', 2017, 10),
#  (27.2, 244.78, 0.16, 'FO', 'MUND', 'MUNDARING_GT1', 2017, 6),
#  (60.98, 243.9, 0.16, 'Forced outage', 'COLLGAR', 'COLLGAR_WF1', 2016, 12),
#  (47.18, 235.91, 0.15, 'Emergency stop of G01 due to turbine oil leak inside package.', 'PMC', 'PMC_AG', 2017, 5),
#  (77.73, 233.2, 0.15, 'FO', 'KORL', 'KORL_GT3', 2016, 6),
#  (116.42, 232.83, 0.15, 'FO', 'PJRH', 'PJRH_GT11', 2017, 8),
#  (12.25, 232.7, 0.15, 'low refinery steam demand', 'AUXC', 'AUXC_WGP', 2016, 12),
#  (116.0, 232.0, 0.15, 'PLC issue taking units out of availability.', 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 1),
#  (57.45, 229.78, 0.15, 'Baghouse issue resulting in restricted load', 'MELK', 'MELK_G7', 2016, 8),
#  (53.61, 214.43, 0.13999999999999999, 'Partial Outage', 'KORL', 'KORL_GT3', 2016, 7),
#  (35.08, 210.5, 0.13999999999999999, 'Loss of auxiliary power on start up.', 'TRMOS', 'TIWEST_COG1', 2016, 4),
#  (26.26, 210.1, 0.13999999999999999, 'Not enough time between Acknowledge Time to Response Time. Discrepancy between SMITTS and KMK generation amount.', 'TRMOS', 'TIWEST_COG1', 2017, 4),
#  (11.96, 203.37, 0.13, 'Refinery Steam/power Imballance', 'AUXC', 'AUXC_WGP', 2016, 9),
#  (18.3, 201.31, 0.13, 'Refinery Steam and Power Imbalance.', 'AUXC', 'AUXC_WGP', 2017, 9),
#  (66.43, 199.3, 0.13, 'Forced outage due to a faulty fire damper limit switch', 'PJRH', 'PJRH_GT11', 2017, 12),
#  (9.85, 197.09, 0.13, 'Ramp Rate Error', 'TRMOS', 'TIWEST_COG1', 2016, 6),
#  (27.21, 190.49, 0.13, 'GTG200B Engine Unavailable', 'PUG', 'PERTHENERGY_KORL_GT1', 2016, 1),
#  (47.53, 190.1, 0.12, 'FO', 'KORL', 'KORL_GT3', 2016, 12),
#  (45.83, 183.33, 0.12, 'Return TX1 to service', 'MCG', 'MWF_MUMBIDA_WF1', 2017, 9),
#  (36.08, 180.4, 0.12, 'Loss of Telemtery from SOCC', 'TRMOS', 'TIWEST_COG1', 2017, 3),
#  (58.0, 174.0, 0.11, 'Station in SCADA control and loading, GT1 TRIP on Grid Disturbance on Safety Integrated System Trip. ', 'PUG', 'PERTHENERGY_KORL_GT1', 2016, 11),
#  (82.65, 165.29, 0.11, 'Loss RTS', 'PJRH', 'PJRH_GT11', 2017, 1),
#  (80.0, 160.0, 0.11, 'Temporary generator supplying LV auxiliary load malfunction.', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016, 12),
#  (53.33, 160.0, 0.11, 'Unit was partially de-rated to perform protection testing.', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017, 3),
#  (31.7, 158.52, 0.1, 'FO', 'PJRH', 'PJRH_GT11', 2017, 7),
#  (79.0, 158.0, 0.1, 'T211 isolated for the repair at CB221 HV termination', 'COLLGAR', 'COLLGAR_WF1', 2017, 11),
#  (77.4, 154.8, 0.1, 'Generation reduced due to GTG100 fault', 'PUG', 'PERTHENERGY_KORL_GT1', 2016, 5),
#  (51.43, 154.29, 0.1, 'FO', 'PJRH', 'PJRH_GT11', 2017, 5),
#  (11.76, 152.9, 0.1, 'Manual Ramp Rate error', 'TRMOS', 'TIWEST_COG1', 2016, 5),
#  (75.05, 150.1, 0.1, 'FO', 'KORL', 'KORL_GT3', 2017, 3),
#  (11.5, 149.51, 0.1, 'refinery issues steam power imbalance\n', 'AUXC', 'AUXC_WGP', 2016, 6),
#  (49.67, 149.0, 0.1, 'GT1 unavailable to run due to Bentley Nevada rack backplane issue, and card failures.', 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 4),
#  (14.72, 147.21, 0.1, 'Gas Turbine breakdown', 'AUXC', 'AUXC_WGP', 2016, 10),
#  (10.41, 145.74, 0.1, 'Refinery Steam & Power Imbalance.', 'AUXC', 'AUXC_WGP', 2017, 1),
#  (48.16, 144.48, 0.09, 'FO', 'KORL', 'KORL_GT3', 2017, 10),
#  (11.95, 143.43, 0.09, 'Incorrect nomination while gas turbine shut down.', 'AUXC', 'AUXC_WGP', 2017, 11),
#  (70.7, 141.4, 0.09, 'Unit unavailable for dispatch', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 7),
#  (46.81, 140.42, 0.09, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2017, 2),
#  (15.29, 137.61, 0.09, 'power steam imbalance', 'AUXC', 'AUXC_WGP', 2017, 5),
#  (136.0, 136.0, 0.09, 'Dispatch Advisory 15998 - Due to a scheduled outage at Merredin Terminal, INVESTEC_COLLGAR_WF1 will be curtailed to 70MW. ', 'COLLGAR', 'COLLGAR_WF1', 2016, 3),
#  (27.2, 136.0, 0.09, 'CG3 Forced Outage', 'COLLGAR', 'COLLGAR_WF1', 2017, 7),
#  (16.69, 133.48, 0.09, 'Refinery Steam / Power Imbalance', 'AUXC', 'AUXC_WGP', 2016, 7),
#  (66.2, 132.4, 0.09, 'Gas Turbine torque convertor failure.', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 10),
#  (26.14, 130.71, 0.09, 'FO', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017, 10),
#  (10.67, 128.0, 0.08, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 6),
#  (42.47, 127.4, 0.08, 'Constrained to 0MW by Western Power due to some SCADA Upgrade', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 5),
#  (63.65, 127.3, 0.08, 'Fire alarm (false alarm) caused the site to go offline and enable signal was removed.', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017, 2),
#  (15.85, 126.78, 0.08, 'Unknown reason for Failure to Comply with Dispatch Obligation', 'TRMOS', 'TIWEST_COG1', 2017, 5),
#  (42.1, 126.3, 0.08, 'Islanded due to Weather conditions', 'TRMOS', 'TIWEST_COG1', 2016, 1),
#  (42.1, 126.3, 0.08, 'Plant Islanded due to severe weather', 'TRMOS', 'TIWEST_COG1', 2016, 9),
#  (42.1, 126.3, 0.08, 'Defective Generator AVR unable to generate power', 'TRMOS', 'TIWEST_COG1', 2016, 12),
#  (10.47, 125.61, 0.08, 'Refinery Issues - Steam,/Power Imbalance', 'AUXC', 'AUXC_WGP', 2016, 3),
#  (20.67, 124.0, 0.08, 'CG 3 - Bird Strike - Pole N24', 'COLLGAR', 'COLLGAR_WF1', 2017, 9),
#  (123.0, 123.0, 0.08, 'FO', 'PJRH', 'PJRH_GT11', 2016, 9),
#  (15.12, 120.94, 0.08, 'Refinery Issues - Steam/Power Imbalance', 'AUXC', 'AUXC_WGP', 2017, 3),
#  (117.4, 117.4, 0.08, 'Unit unavailable for dispatch', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 3),
#  (117.4, 117.4, 0.08, 'Unit unavailable for dispatch', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 6),
#  (117.4, 117.4, 0.08, 'Unit unavailable for dispatch', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 8),
#  (116.0, 116.0, 0.08, 'GT1 Bentley Nevada power supply issue.', 'PUG', 'PERTHENERGY_KORL_GT1', 2016, 10),
#  (37.67, 113.0, 0.06999999999999999, 'FO', 'PJRH', 'PJRH_GT11', 2016, 2),
#  (34.73, 104.2, 0.06999999999999999, 'Load Gearbox vibration inspection over run.', 'TRMOS', 'TIWEST_COG1', 2017, 2),
#  (100.1, 100.1, 0.06999999999999999, 'FO', 'KORL', 'KORL_GT3', 2016, 8),
#  (100.1, 100.1, 0.06999999999999999, 'FO', 'KORL', 'KORL_GT3', 2016, 9),
#  (100.1, 100.1, 0.06999999999999999, 'FO', 'KORL', 'KORL_GT3', 2017, 1),
#  (100.1, 100.1, 0.06999999999999999, 'FO', 'KORL', 'KORL_GT3', 2017, 4),
#  (14.2, 99.4, 0.06999999999999999, 'Constrained by Western Power to 0MW and islanded from the SWIS as per Dispatch Advisory below.\n\nDispatch Advisory ID:17388\n\nDue to the loss of th ... (143 characters truncated) ... eliability. Some Out of Merit generation may occur. Restoration of the line, and removal of the constraint, is not likely to occur until tomorrow. \n', 'AUXC', 'AUXC_WGP', 2017, 10),
#  (32.7, 98.09, 0.06, 'Partial forced outage (pro-rata) due to boiler feed pump trip', 'MELK', 'MELK_G7', 2016, 7),
#  (19.14, 95.71, 0.06, 'Software upgrade of GT', 'AUXC', 'AUXC_WGP', 2017, 8),
#  (23.0, 92.0, 0.06, 'Branch on reactor lead to islanding', 'STHRNCRS', 'STHRNCRS_EG', 2016, 2),
#  (30.19, 90.58, 0.06, 'Forced outage due to master protective start up lockout alarm', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017, 12),
#  (42.1, 84.2, 0.06, 'Failure of Hydraulic Unit on Damper Door', 'TRMOS', 'TIWEST_COG1', 2016, 10),
#  (27.67, 83.0, 0.05, 'MCC fault', 'GW', 'BW1_GREENWATERS_G2', 2016, 12),
#  (11.6, 81.19, 0.05, 'Refinery Steam / Power Imbalance', 'AUXC', 'AUXC_WGP', 2016, 8),
#  (25.8, 77.4, 0.05, 'FO', 'MUND', 'MUNDARING_GT1', 2017, 10),
#  (25.47, 76.4, 0.05, 'FO', 'MUND', 'MUNDARING_GT1', 2017, 7),
#  (12.33, 73.95, 0.05, 'Rotor temperature issue.', 'AURICON', 'AURICON_PNJ_U1', 2016, 3),
#  (10.06, 70.39, 0.05, 'Refinery steam / power imbalance', 'AUXC', 'AUXC_WGP', 2016, 11),
#  (23.0, 69.0, 0.05, 'Break in the communications lines, protection system necessitates minimal transfer down the line to reduce possibility of trip.', 'STHRNCRS', 'STHRNCRS_EG', 2016, 3),
#  (68.0, 68.0, 0.04, 'Planned WP Network Outage', 'PMC', 'PMC_AG', 2016, 12),
#  (11.15, 66.91, 0.04, 'Engine trip due to vibration sensor fault', 'PUG', 'PERTHENERGY_KORL_GT1', 2016, 9),
#  (33.0, 66.0, 0.04, 'Forced outage continuation', 'PMC', 'PMC_AG', 2016, 7),
#  (21.6, 64.8, 0.04, 'WP work', 'EUCT', 'GRASMERE_WF1', 2017, 5),
#  (21.0, 63.0, 0.04, 'Hydraulic oil leak Phase 2 contact clamp', 'GW', 'BW1_GREENWATERS_G2', 2016, 10),
#  (15.74, 62.98, 0.04, 'Gas Valve position fault', 'PUG', 'PERTHENERGY_KORL_GT1', 2016, 8),
#  (8.99, 62.95, 0.04, 'Leaking NOx steam injection line in GT', 'TRMOS', 'TIWEST_COG1', 2016, 7),
#  (10.28, 61.69, 0.04, 'Ramp Rate Error', 'TRMOS', 'TIWEST_COG1', 2016, 8),
#  (20.2, 60.6, 0.04, 'Failure of Damper Door HPU', 'TRMOS', 'TIWEST_COG1', 2017, 1),
#  (55.0, 55.0, 0.04, 'Internal fault', 'MCG', 'MWF_MUMBIDA_WF1', 2016, 11),
#  (55.0, 55.0, 0.04, 'FO', 'MCG', 'MWF_MUMBIDA_WF1', 2017, 6),
#  (18.19, 54.56, 0.04, 'FO', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017, 10),
#  (27.0, 54.0, 0.04, 'CG 3', 'COLLGAR', 'COLLGAR_WF1', 2017, 4),
#  (27.0, 54.0, 0.04, 'FO', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016, 11),
#  (25.24, 50.48, 0.03, 'Issues discovered during planned outage and rectification works are in progress.', 'PMC', 'PMC_AG', 2016, 6),
#  (50.3, 50.3, 0.03, 'GTG200 Inlet guide vane position error at 5:10pm.', 'PUG', 'PERTHENERGY_KORL_GT1', 2016, 7),
#  (6.94, 48.6, 0.03, 'FO', 'EUCT', 'GRASMERE_WF1', 2016, 8),
#  (24.0, 48.0, 0.03, 'FO', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 4),
#  (23.0, 46.0, 0.03, 'GT derated to allow for inspection within package.', 'STHRNCRS', 'STHRNCRS_EG', 2016, 12),
#  (23.0, 46.0, 0.03, 'Minor Control System modifications', 'STHRNCRS', 'STHRNCRS_EG', 2017, 2),
#  (23.0, 46.0, 0.03, 'KNO delayed coming on after planned maintenance.', 'STHRNCRS', 'STHRNCRS_EG', 2017, 5),
#  (42.1, 42.1, 0.03, 'Islanded due to Severe Weather Warning on instruction from Tronox', 'TRMOS', 'TIWEST_COG1', 2016, 3),
#  (42.1, 42.1, 0.03, 'Failure of Damper Door controls', 'TRMOS', 'TIWEST_COG1', 2016, 11),
#  (39.75, 39.75, 0.03, 'Operational issues caused real time forced outage.', 'PMC', 'PMC_AG', 2016, 11),
#  (13.0, 39.0, 0.03, 'Unit tripped after being returned-to-service following a planned outage.', 'STHRNCRS', 'STHRNCRS_EG', 2017, 9),
#  (38.0, 38.0, 0.02, 'FO', 'MUND', 'MUNDARING_GT1', 2016, 1),
#  (37.2, 37.2, 0.02, 'FO', 'MUND', 'MUNDARING_GT1', 2016, 12),
#  (36.0, 36.0, 0.02, 'Forced Off', 'MUND', 'MUNDARING_GT1', 2016, 2),
#  (36.0, 36.0, 0.02, 'FO', 'MUND', 'MUNDARING_GT1', 2016, 11),
#  (17.37, 34.74, 0.02, 'Refinery Issues Steam /Power Imbalance', 'AUXC', 'AUXC_WGP', 2017, 7),
#  (17.0, 34.0, 0.02, 'KNS GT Tripped on vibration alarm, 4 hour lock out.', 'STHRNCRS', 'STHRNCRS_EG', 2017, 12),
#  (16.5, 33.0, 0.02, 'Unexpected behind-the-fence load demand, which reduced the available export capacity.  ', 'STHRNCRS', 'STHRNCRS_EG', 2017, 7),
#  (29.89, 29.89, 0.02, 'Operational Issues caused real time forced outage.', 'GW', 'BW1_GREENWATERS_G2', 2017, 12),
#  (12.8, 25.6, 0.02, 'Refinery steam power imbalance.', 'AUXC', 'AUXC_WGP', 2017, 4),
#  (11.5, 23.0, 0.02, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 2),
#  (23.0, 23.0, 0.02, 'Generator offline for minor maintenance', 'STHRNCRS', 'STHRNCRS_EG', 2016, 4),
#  (23.0, 23.0, 0.02, 'Extension of planned outage due to a faulty cable requiring replacement.', 'STHRNCRS', 'STHRNCRS_EG', 2016, 7),
#  (23.0, 23.0, 0.02, 'Linknet Failure ', 'STHRNCRS', 'STHRNCRS_EG', 2016, 9),
#  (23.0, 23.0, 0.02, 'Delayed end to planned outage', 'STHRNCRS', 'STHRNCRS_EG', 2016, 11),
#  (23.0, 23.0, 0.02, 'WMS 801 and WMK 801 opened due to Phase B being hit by lightening', 'STHRNCRS', 'STHRNCRS_EG', 2017, 1),
#  (23.0, 23.0, 0.02, 'Unit tripped due to high bearing temperature', 'STHRNCRS', 'STHRNCRS_EG', 2017, 3),
#  (19.8, 19.8, 0.01, 'GT Pulsation Monitor PLS', 'COLLGAR', 'COLLGAR_WF1', 2017, 1),
#  (15.7, 15.7, 0.01, 'Unexpected behind-the-fence load demand, which reduced the available export capacity', 'STHRNCRS', 'STHRNCRS_EG', 2017, 6),
#  (12.0, 12.0, 0.01, 'FO', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016, 2),
#  (12.0, 12.0, 0.01, 'Unplanned increase in loads behind-the-fence led to reduction in available capacity to the market', 'STHRNCRS', 'STHRNCRS_EG', 2017, 4),
#  (12.0, 12.0, 0.01, 'An unplanned load increase (?behind-the-fence?) led to a reduction in available capacity', 'STHRNCRS', 'STHRNCRS_EG', 2017, 10),
#  (11.0, 11.0, 0.01, "TES Report - constrained off MW's.", 'PUG', 'PERTHENERGY_KORL_GT1', 2017, 3),
#  (10.8, 10.8, 0.01, 'FO', 'EUCT', 'GRASMERE_WF1', 2016, 7),
#  (9.9, 9.9, 0.01, 'Trip occurred during internal testing. Enable removed until trip reset.', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017, 1),
#  (5.0, 5.0, 0.0, 'Requested by NOCC to constrain to 0MW due to emergency line works on the distribution feeder. ', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017, 7),
#  (5.0, 5.0, 0.0, 'Forced outage due to private distribution line fault.', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017, 9),
#  (5.0, 5.0, 0.0, 'An unplanned load increase (?behind-the-fence?) led to a reduction in available capacity', 'STHRNCRS', 'STHRNCRS_EG', 2017, 8),
#  (4.0, 4.0, 0.0, 'An unplanned load increase (?behind-the-fence?) led to a reduction in available capacity', 'STHRNCRS', 'STHRNCRS_EG', 2017, 11),
#  (1.8, 1.8, 0.0, 'FO', 'EUCT', 'GRASMERE_WF1', 2016, 9),
#  (1.8, 1.8, 0.0, 'FO', 'EUCT', 'GRASMERE_WF1', 2016, 10),
#  (1.8, 1.8, 0.0, 'FO', 'EUCT', 'GRASMERE_WF1', 2016, 11),
#  (1.44, 1.44, 0.0, 'Storm impact on the lower Denmark feeder caused a trip of the windfarm at approx. 8:10 am.  The windfarm was restarted after the faults were cleared at 5:40pm. ', 'DNHR', 'DNHR_DENMARK_WF1', 2016, 8),
#  (1.44, 1.44, 0.0, 'WP maintenance between starting 7 am, return to service approx. 18:45 ', 'DNHR', 'DNHR_DENMARK_WF1', 2017, 2)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(44.16, 21639.55, 14.21, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (85.14, 19326.56, 12.69, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (49.69, 15751.38, 10.34, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Ten </h3>

# %% [markdown]
# <b>Having identified the top 3 participants by Total Energy Loss being `GW`, `MELK` and `Auricon`; Write a SQL Statement calculating the `Total_Energy_Lost` each of these three `Participant_Codes` and the `Facility_Code`. Additionally, identify the `Description_Of_Outage` associated with the highest `Total_Energy_Lost` for each of the `Participant_Codes` and `Facility_Code` for each of the three participants.
#
# <u>Lastly, calculate the percentage of Energy Loss, attributed to these reasons!</u> </b>
#
# <b> ⚠️ Hint: As this is the final question, this is a bit of a <b> challenge question </b> which will involve some SQL functions you're not familiar with just yet. In the workplace, you're going to have to grow familiar with googling and searching for functions that you may have not learned or be familiar with. In this question, to identify the TOP `Description_Of_Outage` reason for each Participant, you're going to need to use `PARTITION BY`. You can read all about the approach you can take in this example <a href = "https://learnsql.com/cookbook/how-to-rank-rows-within-a-partition-in-sql/#:~:text=To%20partition%20rows%20and%20rank,rank%20rows%20within%20a%20partition."> here </a>. Good luck!

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# SELECT *
# FROM
# (SELECT Participant_Code,
#         Facility_Code,
#         Description_Of_Outage,
#         ROUND (SUM (Energy_Lost_MW),2) AS Total_Energy_Lost,
#         ROUND (SUM (Energy_Lost_MW) / (SELECT SUM(Energy_Lost_MW)
#                                              FROM AEMR_Outage_Table
#                                              WHERE Status = 'Approved'
#                                              AND Outage_Reason = 'Forced'),4) * 100 AS Pct_Energy_Loss,
# RANK () OVER (PARTITION BY Participant_Code, Facility_Code ORDER BY SUM(Energy_Lost_MW)DESC) AS Rank
# FROM AEMR_Outage_Table
# WHERE Participant_Code IN ('AURICON','GW','MELK')
#     AND Status = 'Approved'
#     AND Year BETWEEN 2016 AND 2017
#     AND Outage_Reason = 'Forced'
# GROUP BY Participant_Code, Facility_Code, Description_Of_Outage
# ORDER BY Participant_Code, Total_Energy_Lost DESC)
# WHERE Rank = 1;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'AURICON_PNJ_U1', 'Full unit trip', 6033.87, 3.9600000000000004, 1),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational Issues caused real time forced outage.', 28687.54, 18.84, 1),
#  ('MELK', 'MELK_G7', 'Safety Issues', 1100.0, 0.72, 1)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'AURICON_PNJ_U1', 'Full unit trip', 6033.87, 3.96, 1),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational Issues caused real time forced outage.', 28687.54, 18.84, 1),
#  ('MELK', 'MELK_G7', 'Safety Issues', 1100.0, 0.72, 1)]

# %% [markdown]
# Well done! That's a Wrap! We've now analyzed all the data we need to answer Management's Question.
# You'll now move to the next part of your analysis where you'll be proceeding with creating your story in Tableau using the insights you've gathered from your SQL Analysis!
#
# Let's now switch to Part II of our Analysis in Tableau!!
#
# <img src = https://www.energymagazine.com.au/wp-content/uploads/2021/05/shutterstock_1888482466-e1620278098312.jpg>

# %%
import pandas as pd

# %%
df.to_csv('filename.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.to_csv('filename.csv')
#
# NameError: name 'df' is not defined

# %%
# %%sql
# SELECT DISTINCT (Facility_Code)
# FROM AEMR_Outage_Table
# GROUP BY Participant_Code;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON_PNJ_U1',),
#  ('AUXC_WGP',),
#  ('COLLGAR_WF1',),
#  ('DNHR_DENMARK_WF1',),
#  ('ENRG_KALGOORLIE_GT3',),
#  ('GRASMERE_WF1',),
#  ('BW1_GREENWATERS_G2',),
#  ('KORL_GT3',),
#  ('MWF_MUMBIDA_WF1',),
#  ('MELK_G7',),
#  ('MUNDARING_GT1',),
#  ('PJRH_GT11',),
#  ('PMC_AG',),
#  ('PERTHENERGY_KORL_GT1',),
#  ('STHRNCRS_EG',),
#  ('TIWEST_COG1',),
#  ('TESLA_PICTON_G1',),
#  ('WEST_KALGOORLIE_GT2',)]

# %% [markdown]
# ## Appendix: SQL Cheat Sheet
#
# **SELECT**
#
# ```SQL
# - SELECT * FROM table_name -- Select all columns from a table
# - SELECT column_name(s) FROM table_name -- Select some columns from a table
# - SELECT DISTINCT column_name(s) FROM table_name -- Select only the different values
# - SELECT column_name(s) FROM table_name -- Select data filtered with the WHERE clause
#   WHERE condition
# - SELECT column_name(s) FROM table_name -- Order data by multiple columns. DESC for descending
#   ORDER BY column_1, column_2 DESC, column_3 ASC -- and ASC (optional) for ascending order
# ```
#
# **Operators**
# - `<` - Less than
# - `>` - Greater than
# - `<=` - Less than or equal
# - `>=` - Greater than or equal
# - `<>` - Not equal
# - `=` - Equal
# - `BETWEEN v1 AND v2` - Between a specified range
# - `LIKE` - Search pattern. Use `%` as a wildcard. E.g., `%o%` matches "o", "bob", "blob", etc.
#
# **Aggregate Functions**
# - `AVG(column)` - Returns the average value of a column
# - `COUNT(column)` - Returns the number of rows (without a NULL value) of a column
# - `MAX(column)` - Returns the maximum value of a column
# - `MIN(column)` - Returns the minimum value of a column
# - `SUM(column)` - Returns the sum of a column
# ```SQL
# SELECT AVG(column_name), MIN(column_name), MAX(column_name) FROM table_name
# ```
#
# **Miscellaneous**
# - `CASE...END` - Used in `SELECT` queries to alter a variable in place. E.g.
# ```SQL
# SELECT column_name
#     CASE
#         WHEN column_name >= 0 THEN 'POSITIVE'
#         ELSE 'NEGATIVE'
#     END
# FROM table
# ```
# - `AS` - Used to rename a variable. E.g.
# ```SQL
# SELECT SUM(column_name) AS total_column_name FROM table_name
# ```
# - `GROUP BY` - Used to group rows that share the same value(s) in particular column(s). It is mostly used along with aggregation functions
# - `ORDER BY` - Determines the order in which the rows are returned by an SQL query
